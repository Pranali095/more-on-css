# %%
# 1.Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5 navigation links that are properly placed within the navigation bar using the CSS box model. The navigation items must change their text color on hover.

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Navigation Bar</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }
        body {
            font-family: Arial, sans-serif;
        }
        .navbar {
            background-color: #333;
            padding: 15px;
            display: flex;
            justify-content: center;
        }
        .navbar a {
            color: white;
            text-decoration: none;
            padding: 10px 20px;
            margin: 0 10px;
            font-size: 18px;
            transition: color 0.3s;
        }
        .navbar a:hover {
            color: yellow;
        }
    </style>
</head>
<body>
    <nav class="navbar">
        <a href="#">Home</a>
        <a href="#">About</a>
        <a href="#">Services</a>
        <a href="#">Portfolio</a>
        <a href="#">Contact</a>
    </nav>
</body>
</html>

# %%
# 2.Create a div centered with an image and paragraph similar to the image mentioned below.

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>MoreOnCSS</title>
    <style>
         .center-content {
            text-align: center;
            margin-top: 20px;
            background: white;
            padding: 20px;
            border-radius: 10px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
        }
        .center-content img {
            max-width: 100%;
            height: auto;
            border-radius: 10px;
        }
        .center-content p {
            margin-top: 10px;
            font-size: 18px;
            color: #1e1a1a;
        }
    </style>
</head>
<body>
    <div class="center-content">
        <img src="https://blog.hrflow.ai/content/images/2020/04/Full-Stack-Developer.jpg">
        <p>This is sample paragraph centered below the image</p>
    </div>
</body>
</html>

# %%
# 3.Create a navigation bar similar to question 1. For each navigation item, use a different border style.

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <script src="https://cdn.tailwindcss.com"></script>
    <title>Styled Navigation Bar</title>
</head>
<body>
    <nav class="bg-gray-800 p-4">
        <ul class="flex justify-center space-x-6 text-white">
            <li class="border border-solid border-white p-2">Home</li>
            <li class="border-dashed border-2 border-white p-2">About</li>
            <li class="border-double border-4 border-white p-2">Services</li>
            <li class="border-dotted border-2 border-white p-2">Portfolio</li>
            <li class="border-b-4 border-white p-2">Contact</li>
        </ul>
    </nav>
</body>
</html>

# %%
# 4.Create a simple webpage with an image and make the image circular using border-radius.

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> Circular Image Webpage </title>
    <style>
        body {
            display: flex;
            justify-content: center;
            align-items: center;
            height: 100vh;
            background-color: #f4f4f4;
        }
        .image-container {
            text-align: center;
        }
        .circular-image {
            width: 200px;
            height: 200px;
            border-radius: 50%;
            object-fit: cover;
            border: 5px solid #333;
        }
    </style>
</head>
<body>
    <div class="image-container">
        <img src="https://images.pexels.com/photos/1108099/pexels-photo-1108099.jpeg" alt="Circular Image" class="circular-image">
    </div>
</body>
</html>

# %%
# 5.Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font align center to the page, below the heading have an image of Google fonts and a paragraph about Google fonts in font “Montserrat” paragraph font style should be“montserrat” font.

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Google Fonts Blog</title>
    <script src="https://cdn.tailwindcss.com"></script>
    <link href="https://fonts.googleapis.com/css2?family=Oswald:wght@400;700&family=Montserrat:wght@300;400&display=swap" rel="stylesheet">
    <style>
        .oswald { font-family: 'Oswald', sans-serif; }
        .montserrat { font-family: 'Montserrat', sans-serif; }
    </style>
</head>
<body class="bg-gray-100 flex flex-col items-center p-6">
    <h1 class="oswald text-4xl text-center mt-4">Google Fonts</h1>
    <img src="https://upload.wikimedia.org/wikipedia/commons/2/2a/Google_Fonts_logo.svg" alt="Google Fonts Logo" class="my-4 w-64">
    <p class="montserrat text-lg text-gray-700 max-w-2xl text-center">
        Google Fonts is a library of free and open-source font families, launched by Google in 2010. It provides an intuitive and robust directory of web fonts that designers and developers can use in their projects. With a wide range of typefaces, Google Fonts enhances the visual aesthetics of web content while ensuring optimal performance and accessibility.
    </p>
</body>
</html>

# %%
# 6.Create a simple website as mentioned in the below image. You can get the assets by visiting https://pwskills.com/about-us.

<!DOCTYPE html><html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>About Us - PW Skills</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            text-align: center;
        }
        .container {
            width: 80%;
            margin: auto;
            padding: 20px;
        }
        h1 {
            margin-bottom: 10px;
        }
        p {
            font-size: 18px;
            color: #333;
        }
        .image-container {
            margin-top: 20px;
        }
        img {
            width: 100%;
            max-width: 800px;
            height: auto;
            border-radius: 10px;
        }
    </style>
</head>
<body>
    <div class="container">
        <h1>About Us</h1>
        <p>PW Skills' mission is to permeate through every student/professional's outlook towards jobs and change their attitude and perspective from "How Can I Do It?" to "Of Course I Can Do It." We aim to do this by providing exceptional upskilling courses at affordable rates while being tech-forward so anyone, anywhere can access and improve their ability to be successful in life.</p>
        <div class="image-container">
            <img src="assets/aboutUs.png" alt="PW Skills Event">
        </div>
    </div>
</body>
</html>

# %%
# 7. Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.

<!DOCTYPE html><html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>About Us - PW Skills</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            display: flex;
            justify-content: center;
            align-items: center;
            height: 100vh;
            background-color: #f4f4f4;
        }
        .card {
            width: 80%;
            max-width: 600px;
            padding: 20px;
            background: white;
            border-radius: 10px;
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
            text-align: center;
            opacity: 0.5;
            transition: opacity 0.3s ease-in-out;
        }
        .card:hover {
            opacity: 1;
        }
        h1 {
            margin-bottom: 10px;
        }
        p {
            font-size: 18px;
            color: #333;
        }
        .image-container {
            margin-top: 20px;
        }
        img {
            width: 100%;
            max-width: 400px;
            height: auto;
            border-radius: 10px;
        }
    </style>
</head>
<body>
    <div class="card">
        <h1>About Us</h1>
        <p>PW Skills' mission is to permeate through every student/professional's outlook towards jobs and change their attitude and perspective from "How Can I Do It?" to "Of Course I Can Do It." We aim to do this by providing exceptional upskilling courses at affordable rates while being tech-forward so anyone, anywhere can access and improve their ability to be successful in life.</p>
        <div class="image-container">
            <img src="assets/image.jpg" alt="PW Skills Event">
        </div>
    </div>
</body>
</html>

# %%
# 8.Create a simple list of items as mentioned in the below image.

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>List of items</title>
    <style>
        body{
            border-radius: 10px;
        }
        .list{
            margin: 30px;
            border-style: ridge;
            max-width: fit-content;
        }
        h1{
            padding-bottom: 10px;
            margin-left: 10px;
        }
    </style>
</head>
<body>
    <div class="list">
        <h1>Requirements</h1>
        <ol type="i">
            <li>System with minimum i3 processor or better.</li>
            <li>At least 4 GB of RAM.</li>
            <li>Working internet connection.</li>
            <li>Dedication to learn.</li>
        </ol>
    </div>
</body>
</html>
